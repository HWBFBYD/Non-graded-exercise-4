# %% [markdown]
# Write a simple program for a card Role-Playing Game. Try to use only the concepts you have learned so far in the lectures.
#
# REQUIREMENTS:
#
# 1. Following are the different cards, with their characteristics, available to the player
#
# Name: Diablo
# Health: 100
# Attack: 90
# Defense: 60
#
# Name: Medusa
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Jester
# Health: 120
# Attack: 60
# Defense: 90
#
# Name: Troll
# Health: 150
# Attack: 40
# Defense: 94
#
# Name: Specter
# Health: 100
# Attack: 70
# Defense: 70
#
# Name: Mist
# Health: 100
# Attack: 75
# Defense: 65
#
# Name: Savage
# Health: 100
# Attack: 90
# Defense: 50
#
# Name: Marauder
# Health: 100
# Attack: 85
# Defense: 50
#
# Name: Wimp
# Health: 110
# Attack: 40
# Defense: 85
#
# Name: Sorcerer
# Health: 100
# Attack: 70
# Defense: 55
#
# 2. Store the above card details using a suitable data structure like list, tuple, dictionary, or any combination of these
# 3. From these cards, assign a random deck of 5 cards to both the player and the computer (opponent).
#     3.1. This should happen whenever a new game begins
# 4. Keep the game running for as long as there are cards in the player's deck or for as long as there are cards in the opponent's deck
#     4.1. Show all the cards that the player has in their deck
#     4.2. Assign a random card to the opponent, and show that to the player, along with the details of that card. Only the details of this random card must be shown.
#     4.3. Ask the player to pick a card from their own deck to fight the opponent's card.
#     4.4. If the attack value of the player's card is more than the health of opponent's card, then the player wins this round.
#     4.5. Otherwise, the player's card will fight with the opponent's card.
#         4.5.1. Calculate the damage the player's card does to the opponent's card. This calculation should take care of the fact that the opponent's card will first defend the attack using its 'Defense' value. And if there is no defense value, only then will the player's attack value will affect the opponent card's health.
#
#         e.g.,
#         Player card
#
#         Name: Wimp
#         Health: 110
#         Attack: 40
#         Defense: 85
#
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 55
#
#         If the Wimp attacks Sorcerer, first, it will only affect Sorcerer's 'Defense' value. Sorcerer's defense value will decrease by the the attack value of player's Wimp card. Therefore, after the attack, the defense value will change from 55 to 15, as 55 - 40 = 15. Therefore,
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 100
#         Attack: 70
#         Defense: 15
#
#         Now, if in the next round, Wimp attacks Sorcerer again, then Sorcerer's defense value will decrease to 0, but its health will also be affected. The health will be affected by 25 points, as 40 - 15 = 25. So, Sorcerer's health will now decrease from 100 to 75
#
#         Opponent card
#
#         Name: Sorcerer
#         Health: 75
#         Attack: 70
#         Defense: 0
#
#         Now, let's say in a later round, the player uses the Marauder card, which has an attack value of 85, and the computer is using Sorcerer, whose health value is 75.
#
#         In that case, Sorcerer will be defeated, as 85 > 75. When this happens, remove the Sorcerer card from the deck of the opponent.
#
#         Display properly all these changes to the player at every round, so that they know how their attacks affected the round and what they can do next.
#
#         DO NOT just show the card details. Write proper statements, describing the process, as you may have seen in the demonstration given by the teacher
#
#         4.5.2. After the user's turn, make sure all the card values adjusted accordingly, just as described above.
#         4.5.3. ONLY a card's 'Defense' and 'Health' value changes after an attack. And once the 'Health' value of a card reaches 0 or drops below it, that card MUST be removed from the deck.
#         4.5.4. After the player's turn, pause the second for some seconds, e.g., time.sleep(3) will pause the game for 3 seconds.
#     4.6. Display that now it's the opponent's turn.
#     4.7. Make sure there are cards available in opponent's deck. If there aren't, then the game ends and the player wins.
#     4.8. If there are still cards available in opponent's deck, draw a random card from the opponent's deck, and display its details to the player.
#     4.9. Then display the cards available in the player's deck.
#     4.10 Ask the user to pick one card from their own deck to fight the opponent's card.
#     4.11. REPEAT THE SAME LOGIC AS STATED FROM POINT 4.4 TO 4.5.3. But this time, from the perspective of the opponent.
#     4.12. After the opponent's turn is over, display that a new round will begin in some seconds.
# 5. If it's found that the opponent has no card in their deck, then display a message stating player is the winner, otherwise display that the opponent won.

# %%
import random
import time

# Card details stored as dictionaries in a list
card_deck = [
    {"Name": "Diablo", "Health": 100, "Attack": 90, "Defense": 60},
    {"Name": "Medusa", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Jester", "Health": 120, "Attack": 60, "Defense": 90},
    {"Name": "Troll", "Health": 150, "Attack": 40, "Defense": 94},
    {"Name": "Specter", "Health": 100, "Attack": 70, "Defense": 70},
    {"Name": "Mist", "Health": 100, "Attack": 75, "Defense": 65},
    {"Name": "Savage", "Health": 100, "Attack": 90, "Defense": 50},
    {"Name": "Marauder", "Health": 100, "Attack": 85, "Defense": 50},
    {"Name": "Wimp", "Health": 110, "Attack": 40, "Defense": 85},
    {"Name": "Sorcerer", "Health": 100, "Attack": 70, "Defense": 55},
]

# Deck size for both player and opponent
deck_size = 5

# Draw random cards for player and opponent
player_deck = random.sample(card_deck, deck_size)
opponent_deck = random.sample(card_deck, deck_size)

def display_deck(deck, owner):
    """Display the cards of a given deck"""
    print(f"\n{owner}'s deck:")
    for i, card in enumerate(deck, start=1):
        print(f"{i}. Name: {card['Name']}, Health: {card['Health']}, Attack: {card['Attack']}, Defense: {card['Defense']}")

def attack(card1, card2):
    """Handle the attack from card1 to card2, adjusting health and defense values."""
    attack_val = card1["Attack"]
    if attack_val > card2["Defense"]:
        damage_to_health = attack_val - card2["Defense"]
        card2["Health"] -= damage_to_health
        card2["Defense"] = 0
    else:
        card2["Defense"] -= attack_val
        damage_to_health = 0

    return damage_to_health

def game_round():
    """Perform a round of attack between player and opponent"""
    while player_deck and opponent_deck:
        # Display player's deck
        display_deck(player_deck, "Player")

        # Opponent draws a random card
        opponent_card = random.choice(opponent_deck)
        print(f"\nOpponent drew a card: {opponent_card['Name']} (Health: {opponent_card['Health']}, Attack: {opponent_card['Attack']}, Defense: {opponent_card['Defense']})")

        # Player chooses a card to fight
        choice = int(input("\nChoose a card from your deck to fight (1-5): ")) - 1
        player_card = player_deck[choice]

        print(f"\nYou chose: {player_card['Name']} (Health: {player_card['Health']}, Attack: {player_card['Attack']}, Defense: {player_card['Defense']})")

        # Player attacks opponent
        if player_card["Attack"] >= opponent_card["Health"]:
            print(f"\n{player_card['Name']} defeats {opponent_card['Name']}!")
            opponent_deck.remove(opponent_card)
        else:
            damage = attack(player_card, opponent_card)
            print(f"\n{player_card['Name']} attacks {opponent_card['Name']}, causing {damage} damage.")
            print(f"{opponent_card['Name']}'s Health is now {opponent_card['Health']} and Defense is {opponent_card['Defense']}.")

        time.sleep(3)  # Pause for 3 seconds before the opponent's turn

        # Opponent's turn
        if opponent_deck:
            print("\nOpponent's turn...")
            opponent_card = random.choice(opponent_deck)
            player_card = random.choice(player_deck)

            print(f"\nOpponent chose: {opponent_card['Name']} (Health: {opponent_card['Health']}, Attack: {opponent_card['Attack']}, Defense: {opponent_card['Defense']})")
            print(f"Your card: {player_card['Name']} (Health: {player_card['Health']}, Attack: {player_card['Attack']}, Defense: {player_card['Defense']})")

            if opponent_card["Attack"] >= player_card["Health"]:
                print(f"\n{opponent_card['Name']} defeats {player_card['Name']}!")
                player_deck.remove(player_card)
            else:
                damage = attack(opponent_card, player_card)
                print(f"\n{opponent_card['Name']} attacks {player_card['Name']}, causing {damage} damage.")
                print(f"{player_card['Name']}'s Health is now {player_card['Health']} and Defense is {player_card['Defense']}.")

        time.sleep(3)  # Pause for 3 seconds before the next round

    if not player_deck:
        print("\nThe opponent won!")
    else:
        print("\nCongratulations, you won!")

# Start the game
game_round()
# Out:
# Player's deck:
# 1. Name: Medusa, Health: 100, Attack: 70, Defense: 70
# 2. Name: Mist, Health: 100, Attack: 75, Defense: 65
# 3. Name: Jester, Health: 120, Attack: 60, Defense: 90
# 4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# 5. Name: Marauder, Health: 100, Attack: 85, Defense: 50
#
# Opponent drew a card: Diablo (Health: 100, Attack: 90, Defense: 60)
#
# You chose: Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Marauder attacks Diablo, causing 25 damage.
# Diablo's Health is now 75 and Defense is 0.
#
# Opponent's turn...
#
# Opponent chose: Diablo (Health: 75, Attack: 90, Defense: 0)
# Your card: Mist (Health: 100, Attack: 75, Defense: 65)
#
# Diablo attacks Mist, causing 25 damage.
# Mist's Health is now 75 and Defense is 0.
#
# Player's deck:
# 1. Name: Medusa, Health: 100, Attack: 70, Defense: 70
# 2. Name: Mist, Health: 75, Attack: 75, Defense: 0
# 3. Name: Jester, Health: 120, Attack: 60, Defense: 90
# 4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# 5. Name: Marauder, Health: 100, Attack: 85, Defense: 50
#
# Opponent drew a card: Medusa (Health: 100, Attack: 70, Defense: 70)
#
# You chose: Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Marauder attacks Medusa, causing 15 damage.
# Medusa's Health is now 85 and Defense is 0.
#
# Opponent's turn...
#
# Opponent chose: Savage (Health: 100, Attack: 90, Defense: 50)
# Your card: Marauder (Health: 100, Attack: 85, Defense: 50)
#
# Savage attacks Marauder, causing 40 damage.
# Marauder's Health is now 60 and Defense is 0.
#
# Player's deck:
# 1. Name: Medusa, Health: 85, Attack: 70, Defense: 0
# 2. Name: Mist, Health: 75, Attack: 75, Defense: 0
# 3. Name: Jester, Health: 120, Attack: 60, Defense: 90
# 4. Name: Wimp, Health: 110, Attack: 40, Defense: 85
# 5. Name: Marauder, Health: 60, Attack: 85, Defense: 0
#
# Opponent drew a card: Marauder (Health: 60, Attack: 85, Defense: 0)
#
# You chose: Jester (Health: 120, Attack: 60, Defense: 90)
#
# Jester defeats Marauder!
#
# Opponent's turn...
#
# Opponent chose: Savage (Health: 100, Attack: 90, Defense: 50)
# Your card: Wimp (Health: 110, Attack: 40, Defense: 85)
#
# Savage attacks Wimp, causing 5 damage.
# Wimp's Health is now 105 and Defense is 0.
#
# Player's deck:
# 1. Name: Medusa, Health: 85, Attack: 70, Defense: 0
# 2. Name: Mist, Health: 75, Attack: 75, Defense: 0
# 3. Name: Jester, Health: 120, Attack: 60, Defense: 90
# 4. Name: Wimp, Health: 105, Attack: 40, Defense: 0
# 5. Name: Marauder, Health: 60, Attack: 85, Defense: 0
#
# Opponent drew a card: Diablo (Health: 75, Attack: 90, Defense: 0)
#
# You chose: Mist (Health: 75, Attack: 75, Defense: 0)
#
# Mist defeats Diablo!
#
# Opponent's turn...
#
# Opponent chose: Mist (Health: 75, Attack: 75, Defense: 0)
# Your card: Wimp (Health: 105, Attack: 40, Defense: 0)
#
# Mist attacks Wimp, causing 75 damage.
# Wimp's Health is now 30 and Defense is 0.
#
# Player's deck:
# 1. Name: Medusa, Health: 85, Attack: 70, Defense: 0
# 2. Name: Mist, Health: 75, Attack: 75, Defense: 0
# 3. Name: Jester, Health: 120, Attack: 60, Defense: 90
# 4. Name: Wimp, Health: 30, Attack: 40, Defense: 0
# 5. Name: Marauder, Health: 60, Attack: 85, Defense: 0
#
# Opponent drew a card: Savage (Health: 100, Attack: 90, Defense: 50)
#
# You chose: Marauder (Health: 60, Attack: 85, Defense: 0)
#
# Marauder attacks Savage, causing 35 damage.
# Savage's Health is now 65 and Defense is 0.
#
# Opponent's turn...
#
# Opponent chose: Savage (Health: 65, Attack: 90, Defense: 0)
# Your card: Jester (Health: 120, Attack: 60, Defense: 90)
#
# Savage attacks Jester, causing 0 damage.
# Jester's Health is now 120 and Defense is 0.
#
# Player's deck:
# 1. Name: Medusa, Health: 85, Attack: 70, Defense: 0
# 2. Name: Mist, Health: 75, Attack: 75, Defense: 0
# 3. Name: Jester, Health: 120, Attack: 60, Defense: 0
# 4. Name: Wimp, Health: 30, Attack: 40, Defense: 0
# 5. Name: Marauder, Health: 60, Attack: 85, Defense: 0
#
# Opponent drew a card: Savage (Health: 65, Attack: 90, Defense: 0)
#
# You chose: Medusa (Health: 85, Attack: 70, Defense: 0)
#
# Medusa defeats Savage!
#
# Opponent's turn...
#
# Opponent chose: Mist (Health: 75, Attack: 75, Defense: 0)
# Your card: Jester (Health: 120, Attack: 60, Defense: 0)
#
# Mist attacks Jester, causing 75 damage.
# Jester's Health is now 45 and Defense is 0.
#
# Player's deck:
# 1. Name: Medusa, Health: 85, Attack: 70, Defense: 0
# 2. Name: Mist, Health: 75, Attack: 75, Defense: 0
# 3. Name: Jester, Health: 45, Attack: 60, Defense: 0
# 4. Name: Wimp, Health: 30, Attack: 40, Defense: 0
# 5. Name: Marauder, Health: 60, Attack: 85, Defense: 0
#
# Opponent drew a card: Mist (Health: 75, Attack: 75, Defense: 0)
#
# You chose: Mist (Health: 75, Attack: 75, Defense: 0)
#
# Mist defeats Mist!
#
# Opponent's turn...
#
# Opponent chose: Medusa (Health: 85, Attack: 70, Defense: 0)
# Your card: Medusa (Health: 85, Attack: 70, Defense: 0)
#
# Medusa attacks Medusa, causing 70 damage.
# Medusa's Health is now 15 and Defense is 0.
#
# Player's deck:
# 1. Name: Medusa, Health: 15, Attack: 70, Defense: 0
# 2. Name: Mist, Health: 75, Attack: 75, Defense: 0
# 3. Name: Jester, Health: 45, Attack: 60, Defense: 0
# 4. Name: Wimp, Health: 30, Attack: 40, Defense: 0
# 5. Name: Marauder, Health: 60, Attack: 85, Defense: 0
#
# Opponent drew a card: Medusa (Health: 15, Attack: 70, Defense: 0)
#
# You chose: Wimp (Health: 30, Attack: 40, Defense: 0)
#
# Wimp defeats Medusa!
#
# Congratulations, you won!
